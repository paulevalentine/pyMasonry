# %%
# %load_ext autoreload
# %autoreload 2
import compressiveMasonry as mas

# %%
a = mas.Wall(1.38 * 7.3,4,0.75,2700,100,102)
b = mas.Wall(1.38*3.5,4,0.75,2400,100,102)

# %%
b.print_design_vertical_capacity()
# Out:
# hef = 2400.00mm, twall = 100.00mm
# fk = 3.42MPa : Phi = 0.54
# Design vertical load capacity of the wall = 68.55 kN/m
