# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import structuralMasonry as m
import compressiveMasonry as cm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = m.Masonry(6,4,"brick")
# Out:
# Calculate characteristic compressive strength of masonry (MPa):
#           α   β
# fₖ = K⋅f_b ⋅fₘ
# fₖ = 2.66
# Calculate the elastic modulus for the masonry (MPa):
# Eₘ = 1000⋅fₖ
# Eₘ = 2.66e+3

# %%
b = cm.Wall(1.38*7.3,4,"block",2400,100,102)
# Out:
# Calculate characteristic compressive strength of masonry (MPa):
#           α   β
# fₖ = K⋅f_b ⋅fₘ
# fₖ = 5.73
# Calculate the elastic modulus for the masonry (MPa):
# Eₘ = 1000⋅fₖ
# Eₘ = 5.73e+3
# Calculate the effective thickness of the wall (mm):
#         ___________
#      3 ╱   3     3
# tₑ = ╲╱  t₁  + t₂
# tₑ = 127.3
# Calculate the eccentricity at the top of the wall (mm):
#              h_eff
# e_c = eₜₒₚ + ─────
#               450
# e_c = 10.33
# eₘᵢₙ = 0.05⋅t
# eₘᵢₙ = 5.0
# eₜ = 10.33
# Calculate the strength reduction factor for the top of the wall:
#         2⋅eₜ
# φ = 1 - ────
#          t
# φ = 0.79
# Calculate the eccentricity at mid-height of the wall (mm):
#      eₜₒₚ   h_ef
# eₘ = ──── + ────
#       2     450
# eₘ = 7.833
#                           ______
#      0.002⋅h_ef⋅φ_creep⋅╲╱ eₘ⋅t
# eₖ = ───────────────────────────
#                 t_ef
# eₖ = 1.583
# eₘₖ = eₖ + eₘ
# eₘₖ = 9.417
# eₘᵢₙ = 5.0
# ...

# %%
p = cm.Padstone(1.38*7.3,4,"block",000,2000,2400,440,100)
# Out:
# Calculate characteristic compressive strength of masonry (MPa):
#           α   β
# fₖ = K⋅f_b ⋅fₘ
# fₖ = 5.73
# Calculate the elastic modulus for the masonry (MPa):
# Eₘ = 1000⋅fₖ
# Eₘ = 5.73e+3
# Calculate the area of the padstone (mm2)
# A_b = l⋅w
# A_b = 44000.0
# Calculate the effective spread at mid-height based on 60 Deg angle and side constraints:
# l_eff = 1132.82
# A_eff = l_eff⋅t
# A_eff = 113282.0
#       ⎛    0.3⋅aₘᵢₙ⎞ ⎛      1.1⋅A_b⎞
# β_c = ⎜1 + ────────⎟⋅⎜1.5 - ───────⎟
#       ⎝       h    ⎠ ⎝       A_eff ⎠
# β_c = 1.07
# Apply BS EN 1996-1-1 limits:
# β = 1.07
# Calculate the capacity of the padstone (kN):
#        0.001⋅A_b⋅β⋅fk
# N_Rd = ──────────────
#             γ_m.
# N_Rd = 100.1
