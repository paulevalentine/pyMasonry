# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import structuralMasonry as m
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = m.Masonry(6,4,0.75)
# Out:
# Calculate characteristic compressive strength of masonry (MPa):
# Eq(f_k, K*f_b**alpha*f_m**beta)
# Eq(f_k, 3.98)
# Calculate the elastic modulus for the masonry (MPa):
# Eq(E_m, 1000*f_k)
# Eq(E_m, 3.98e+3)

# %%
a.test_value("AA", "Type A")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a.test_value("AA", "Type A")
#
# AttributeError: 'Masonry' object has no attribute 'test_value'
