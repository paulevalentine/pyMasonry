# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import structuralMasonry as m
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = m.Masonry(6,4,0.75)

# %%
a.test_value("AA", "Type A")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 a.test_value("AA", "Type A")
#
# File ~/code/pyMasonry/src/structuralMasonry.py:4, in test_value(self, x, y)
#       3 class Masonry():
# ----> 4     def __init__(self,fb:float,fm:float,k:float)->None:
#       5         """ define the main properties of the masonry """
#       6         self.fb: float = fb # normalised compressive strenght of the unit
#
# File ~/code/pyMasonry/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:2576, in _AtIndexer.__getitem__(self, key)
#    2573         raise ValueError("Invalid call for scalar access (getting)!")
#    2574     return self.obj.loc[key]
# -> 2576 return super().__getitem__(key)
#
# File ~/code/pyMasonry/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:2528, in _ScalarAccessIndexer.__getitem__(self, key)
# ...
