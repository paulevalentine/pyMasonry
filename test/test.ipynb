# %%
# %load_ext autoreload
# %autoreload 2
import compressiveMasonry as mas
import calculationsMasonry as calcs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = mas.Wall(1.38 * 3.5,6,0.75,2400,100,102)
a.print_design_vertical_capacity()
# Out:
# hef = 2400.00mm, twall = 100.00mm
# fk = 3.87MPa : Phi_top = 0.79 : Phi_mid = 0.56
# Design vertical load capacity of the wall = 80.26 kN/m

# %%
pier_load = calcs.pier_load(1.8,0.44,0,2.4,25)
# Out:
# The maximum UDL on the pier = 76.14kN/m
